# %% [markdown]
# Google Colab:
# https://colab.research.google.com/drive/1m6eCbiMrlshZY9w-I96KbNAYCKMsqJID

# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd gdrive/My Drive
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# [Errno 2] No such file or directory: 'cupoy_cv_part4 # 可以自己改路徑'
# /content/gdrive/My Drive

# %%
% cd cupoy_cv_part4
# Out:
# /content/gdrive/My Drive/cupoy_cv_part4

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 0.0049 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00204, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00204 to 0.00191, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00187, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00187 to 0.00187, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 221us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00187
# Epoch 6/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 9.9435e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00187 to 0.00172, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 8.5285e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00172 to 0.00162, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 7.4278e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss improved from 0.00162 to 0.00153, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 6.5378e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00153 to 0.00134, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 5.7021e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00134 to 0.00122, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 5.1581e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00122 to 0.00115, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 4.8068e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00115 to 0.00111, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 4.4461e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00111
# Epoch 14/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 4.2152e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00111 to 0.00105, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 3.9941e-04 - val_loss: 9.3113e-04
#
# Epoch 00015: val_loss improved from 0.00105 to 0.00093, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 3.7316e-04 - val_loss: 9.3094e-04
#
# Epoch 00016: val_loss improved from 0.00093 to 0.00093, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 3.4963e-04 - val_loss: 9.1070e-04
#
# Epoch 00017: val_loss improved from 0.00093 to 0.00091, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 3.3571e-04 - val_loss: 9.2442e-04
#
# Epoch 00018: val_loss did not improve from 0.00091
# Epoch 19/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 3.2321e-04 - val_loss: 9.7343e-04
#
# Epoch 00019: val_loss did not improve from 0.00091
# Epoch 20/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 3.2168e-04 - val_loss: 8.4442e-04
#
# Epoch 00020: val_loss improved from 0.00091 to 0.00084, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 3.0906e-04 - val_loss: 9.1124e-04
#
# Epoch 00021: val_loss did not improve from 0.00084
# Epoch 22/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 2.9013e-04 - val_loss: 8.8317e-04
#
# Epoch 00022: val_loss did not improve from 0.00084
# Epoch 23/150
# 1712/1712 [==============================] - 0s 234us/step - loss: 2.9430e-04 - val_loss: 8.4462e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 2.8433e-04 - val_loss: 8.5977e-04
#
# Epoch 00024: val_loss did not improve from 0.00084
# Epoch 25/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.7290e-04 - val_loss: 8.7779e-04
#
# Epoch 00025: val_loss did not improve from 0.00084
# Epoch 26/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.6322e-04 - val_loss: 8.6848e-04
#
# Epoch 00026: val_loss did not improve from 0.00084
# Epoch 27/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 2.5937e-04 - val_loss: 8.2981e-04
#
# Epoch 00027: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 2.5407e-04 - val_loss: 8.3568e-04
#
# Epoch 00028: val_loss did not improve from 0.00083
# Epoch 29/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 2.4744e-04 - val_loss: 8.1604e-04
#
# Epoch 00029: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 2.4453e-04 - val_loss: 8.3641e-04
#
# Epoch 00030: val_loss did not improve from 0.00082
# Epoch 31/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 2.2660e-04 - val_loss: 7.9742e-04
#
# Epoch 00031: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.2627e-04 - val_loss: 8.0144e-04
#
# Epoch 00032: val_loss did not improve from 0.00080
# Epoch 33/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 2.2380e-04 - val_loss: 8.1652e-04
#
# Epoch 00033: val_loss did not improve from 0.00080
# Epoch 34/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 2.1915e-04 - val_loss: 8.0638e-04
#
# Epoch 00034: val_loss did not improve from 0.00080
# Epoch 35/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 2.2338e-04 - val_loss: 8.4711e-04
#
# Epoch 00035: val_loss did not improve from 0.00080
# Epoch 36/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 2.2433e-04 - val_loss: 8.9195e-04
#
# Epoch 00036: val_loss did not improve from 0.00080
# Epoch 37/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 2.1377e-04 - val_loss: 8.0714e-04
#
# Epoch 00037: val_loss did not improve from 0.00080
# Epoch 38/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 2.0145e-04 - val_loss: 8.1099e-04
#
# Epoch 00038: val_loss did not improve from 0.00080
# Epoch 39/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 2.0696e-04 - val_loss: 7.7119e-04
#
# Epoch 00039: val_loss improved from 0.00080 to 0.00077, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.9463e-04 - val_loss: 8.1411e-04
#
# Epoch 00040: val_loss did not improve from 0.00077
# Epoch 41/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.9587e-04 - val_loss: 7.9893e-04
#
# Epoch 00041: val_loss did not improve from 0.00077
# Epoch 42/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.9684e-04 - val_loss: 7.8440e-04
#
# Epoch 00042: val_loss did not improve from 0.00077
# Epoch 43/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.9550e-04 - val_loss: 8.2955e-04
#
# Epoch 00043: val_loss did not improve from 0.00077
# Epoch 44/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.9569e-04 - val_loss: 7.8412e-04
#
# Epoch 00044: val_loss did not improve from 0.00077
# Epoch 45/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.8483e-04 - val_loss: 7.8789e-04
#
# Epoch 00045: val_loss did not improve from 0.00077
# Epoch 46/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.8521e-04 - val_loss: 7.7135e-04
#
# Epoch 00046: val_loss did not improve from 0.00077
# Epoch 47/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.8824e-04 - val_loss: 7.6365e-04
#
# Epoch 00047: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.7822e-04 - val_loss: 7.9387e-04
#
# Epoch 00048: val_loss did not improve from 0.00076
# Epoch 49/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 1.7584e-04 - val_loss: 7.6421e-04
#
# Epoch 00049: val_loss did not improve from 0.00076
# Epoch 50/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.6991e-04 - val_loss: 8.3317e-04
#
# Epoch 00050: val_loss did not improve from 0.00076
# Epoch 51/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.7533e-04 - val_loss: 7.7275e-04
#
# Epoch 00051: val_loss did not improve from 0.00076
# Epoch 52/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.7054e-04 - val_loss: 7.5581e-04
#
# Epoch 00052: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 53/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.7505e-04 - val_loss: 8.0047e-04
#
# Epoch 00053: val_loss did not improve from 0.00076
# Epoch 54/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.6504e-04 - val_loss: 7.9222e-04
#
# Epoch 00054: val_loss did not improve from 0.00076
# Epoch 55/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.6134e-04 - val_loss: 7.7432e-04
#
# Epoch 00055: val_loss did not improve from 0.00076
# Epoch 56/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.5704e-04 - val_loss: 7.8544e-04
#
# Epoch 00056: val_loss did not improve from 0.00076
# Epoch 57/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.6046e-04 - val_loss: 7.7709e-04
#
# Epoch 00057: val_loss did not improve from 0.00076
# Epoch 58/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.5821e-04 - val_loss: 8.0618e-04
#
# Epoch 00058: val_loss did not improve from 0.00076
# Epoch 59/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.5378e-04 - val_loss: 7.6312e-04
#
# Epoch 00059: val_loss did not improve from 0.00076
# Epoch 60/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.5694e-04 - val_loss: 8.0130e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.4973e-04 - val_loss: 7.5600e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 1.5011e-04 - val_loss: 7.6224e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 1.5009e-04 - val_loss: 8.1272e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.4995e-04 - val_loss: 7.5878e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.5077e-04 - val_loss: 7.8827e-04
#
# Epoch 00065: val_loss did not improve from 0.00076
# Epoch 66/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 1.4631e-04 - val_loss: 7.9475e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 1.4752e-04 - val_loss: 8.1673e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.4518e-04 - val_loss: 7.6773e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 0s 209us/step - loss: 1.4167e-04 - val_loss: 7.6154e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.3962e-04 - val_loss: 7.5941e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.3739e-04 - val_loss: 7.8199e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.3498e-04 - val_loss: 7.6163e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.3280e-04 - val_loss: 8.3295e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.3200e-04 - val_loss: 7.7673e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.3283e-04 - val_loss: 7.8055e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.3171e-04 - val_loss: 7.8262e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.3026e-04 - val_loss: 7.8100e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.3162e-04 - val_loss: 8.2824e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.2606e-04 - val_loss: 7.7425e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.2588e-04 - val_loss: 7.6479e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 1.3471e-04 - val_loss: 7.5802e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.2797e-04 - val_loss: 7.6328e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.2828e-04 - val_loss: 7.4882e-04
#
# Epoch 00083: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 84/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.2694e-04 - val_loss: 8.0123e-04
#
# Epoch 00084: val_loss did not improve from 0.00075
# Epoch 85/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.2674e-04 - val_loss: 7.8945e-04
#
# Epoch 00085: val_loss did not improve from 0.00075
# Epoch 86/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.2454e-04 - val_loss: 7.9205e-04
#
# Epoch 00086: val_loss did not improve from 0.00075
# Epoch 87/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.2033e-04 - val_loss: 7.8488e-04
#
# Epoch 00087: val_loss did not improve from 0.00075
# Epoch 88/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.2152e-04 - val_loss: 8.0767e-04
#
# Epoch 00088: val_loss did not improve from 0.00075
# Epoch 89/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.1951e-04 - val_loss: 7.9077e-04
#
# Epoch 00089: val_loss did not improve from 0.00075
# Epoch 90/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.1892e-04 - val_loss: 7.9866e-04
#
# Epoch 00090: val_loss did not improve from 0.00075
# Epoch 91/150
# 1712/1712 [==============================] - 0s 229us/step - loss: 1.1875e-04 - val_loss: 7.9318e-04
#
# Epoch 00091: val_loss did not improve from 0.00075
# Epoch 92/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.1564e-04 - val_loss: 8.1419e-04
#
# Epoch 00092: val_loss did not improve from 0.00075
# Epoch 93/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 1.1276e-04 - val_loss: 8.4135e-04
#
# Epoch 00093: val_loss did not improve from 0.00075
# Epoch 94/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.1569e-04 - val_loss: 7.9828e-04
#
# Epoch 00094: val_loss did not improve from 0.00075
# Epoch 95/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.1559e-04 - val_loss: 7.9605e-04
#
# Epoch 00095: val_loss did not improve from 0.00075
# Epoch 96/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.1377e-04 - val_loss: 7.7527e-04
#
# Epoch 00096: val_loss did not improve from 0.00075
# Epoch 97/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 1.1482e-04 - val_loss: 7.9309e-04
#
# Epoch 00097: val_loss did not improve from 0.00075
# Epoch 98/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.0838e-04 - val_loss: 7.8550e-04
#
# Epoch 00098: val_loss did not improve from 0.00075
# Epoch 99/150
# 1712/1712 [==============================] - 0s 219us/step - loss: 1.0765e-04 - val_loss: 7.6080e-04
#
# Epoch 00099: val_loss did not improve from 0.00075
# Epoch 100/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.1376e-04 - val_loss: 7.7965e-04
#
# Epoch 00100: val_loss did not improve from 0.00075
# Epoch 101/150
# 1712/1712 [==============================] - 0s 210us/step - loss: 1.0852e-04 - val_loss: 7.6077e-04
#
# Epoch 00101: val_loss did not improve from 0.00075
# Epoch 102/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.0630e-04 - val_loss: 7.5340e-04
#
# Epoch 00102: val_loss did not improve from 0.00075
# Epoch 103/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.0724e-04 - val_loss: 7.4652e-04
#
# Epoch 00103: val_loss improved from 0.00075 to 0.00075, saving model to best_weights.h5
# Epoch 104/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.0630e-04 - val_loss: 8.1301e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 1.0816e-04 - val_loss: 8.0132e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 1.0373e-04 - val_loss: 8.1355e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 1.0406e-04 - val_loss: 7.6543e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 1.0277e-04 - val_loss: 7.8945e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 0s 218us/step - loss: 1.0405e-04 - val_loss: 7.6866e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 0s 220us/step - loss: 1.0391e-04 - val_loss: 7.9021e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 1.0303e-04 - val_loss: 7.9121e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 1.0681e-04 - val_loss: 7.4966e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 0s 232us/step - loss: 1.0387e-04 - val_loss: 7.8877e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 1.0096e-04 - val_loss: 7.4397e-04
#
# Epoch 00114: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 115/150
# 1712/1712 [==============================] - 0s 222us/step - loss: 9.9536e-05 - val_loss: 7.9223e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.8781e-05 - val_loss: 7.7155e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 9.9838e-05 - val_loss: 7.8584e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 9.6059e-05 - val_loss: 7.4836e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 9.6595e-05 - val_loss: 7.8889e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 0s 226us/step - loss: 9.4432e-05 - val_loss: 7.6753e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 9.4623e-05 - val_loss: 7.8721e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.5330e-05 - val_loss: 7.8019e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 9.7231e-05 - val_loss: 7.5431e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 9.6810e-05 - val_loss: 7.6791e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 0s 211us/step - loss: 9.6235e-05 - val_loss: 7.7313e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 0s 227us/step - loss: 9.5396e-05 - val_loss: 7.8651e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 9.3435e-05 - val_loss: 7.7118e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 0s 224us/step - loss: 9.5634e-05 - val_loss: 7.5945e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 9.4189e-05 - val_loss: 7.8732e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 0s 241us/step - loss: 9.0751e-05 - val_loss: 7.8202e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 0s 223us/step - loss: 8.9914e-05 - val_loss: 7.8712e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 8.8126e-05 - val_loss: 7.8669e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 8.7546e-05 - val_loss: 7.9125e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 8.8747e-05 - val_loss: 7.8061e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.6947e-05 - val_loss: 7.7202e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 8.7063e-05 - val_loss: 7.7933e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 9.0414e-05 - val_loss: 7.9229e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.7019e-05 - val_loss: 7.7458e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 8.8511e-05 - val_loss: 7.8608e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 0s 214us/step - loss: 8.6448e-05 - val_loss: 7.4962e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.7678e-05 - val_loss: 7.6750e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 8.6283e-05 - val_loss: 7.7742e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 0s 215us/step - loss: 8.6955e-05 - val_loss: 7.9292e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 8.7193e-05 - val_loss: 7.8336e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 0s 217us/step - loss: 8.6155e-05 - val_loss: 7.5334e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 0s 225us/step - loss: 8.3956e-05 - val_loss: 8.2946e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 0s 228us/step - loss: 8.5000e-05 - val_loss: 8.1148e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 0s 216us/step - loss: 8.4346e-05 - val_loss: 7.8815e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 0s 212us/step - loss: 8.2857e-05 - val_loss: 7.7007e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 0s 213us/step - loss: 8.0755e-05 - val_loss: 7.7374e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
