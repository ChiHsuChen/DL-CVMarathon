# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiHsuChen/DL-CVMarathon/blob/master/Day001_read_image_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# _*_ coding: utf-8 _*_
# _*_ coding: cp950 _*_

# author: Chi-Hsu Chen (css920@gmail.com)
# purpose: Day001_read_image_HW.ipynb
# datetime: 20200528

import numpy as np
import cv2
import urllib
from google.colab.patches import cv2_imshow

def url_to_image(url):
	response = urllib.request.urlopen(url)
	image = np.asarray(bytearray(response.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
	return image

# main
imgSourceFromURL=url_to_image("http://optipng.sourceforge.net/pngtech/img/lena.png")
if imgSourceFromURL is None:
  print("imgSourceFromURL is nothing.SKIP...")
  exit

# SORRY! cv2.imshow is disabled @ COLAB. Here is some work-around
imgColor=cv2.cvtColor(imgSourceFromURL,cv2.COLOR_BGR2BGRA)
imgGray=cv2.cvtColor(imgSourceFromURL,cv2.COLOR_BGR2GRAY)

cv2_imshow(imgColor)
cv2_imshow(imgGray)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512 at 0x7FF53B959F98>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FF53B9594A8>
